# %%
import graphlab as gl
import pandas as pd!
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-37-a346f5c8ba51> in <module>()
#       1 import graphlab as gl
# ----> 2 import pandas as pd
#
# /Users/shri/anaconda3/envs/gl-env/lib/python2.7/site-packages/pandas/__init__.py in <module>()
#      21
#      22 # numpy compat
# ---> 23 from pandas.compat.numpy import *
#      24
#      25 try:
#
# ImportError: No module named numpy

# %%
! conda install -c anaconda numpy
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /Users/shri/anaconda3/envs/gl-env
#
#   added / updated specs:
#     - numpy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     numpy-1.10.4               |           py27_0         3.0 MB  anaconda
#     openssl-1.0.2g             |                0         3.0 MB  anaconda
#     ------------------------------------------------------------
#                                            Total:         6.0 MB
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   numpy                                           pkgs/free --> anaconda
#   openssl                                         pkgs/free --> anaconda
#
#
# Proceed ([y]/n)? ^C
# CondaSystemExit:
# Operation aborted.  Exiting.

# %%
! pip install --upgrade pandas
# Out:
# ...
#     100% |################################| 16.7MB 32kB/s
# ...
#     100% |################################| 512kB 480kB/s
# ...
#     100% |################################| 235kB 540kB/s
# ...
#     100% |################################| 13.9MB 40kB/s
# Requirement already up-to-date: six>=1.5 in /Users/shri/anaconda3/envs/gl-env/lib/python2.7/site-packages (from python-dateutil>=2.5.0->pandas)
# ...
#   Found existing installation: pytz 2016.2
#     DEPRECATION: Uninstalling a distutils installed project (pytz) has been deprecated and will be removed in a future version. This is due to the fact that uninstalling a distutils project will only partially uninstall the project.
#     Uninstalling pytz-2016.2:
#       Successfully uninstalled pytz-2016.2
#   Found existing installation: python-dateutil 2.7.5
#     Uninstalling python-dateutil-2.7.5:
#       Successfully uninstalled python-dateutil-2.7.5
#   Found existing installation: numpy 1.10.4
# ...

# %%
loans=gl.SFrame('data_set/lending-club-data.gl/')
loans.head(5)
# Out:
# Columns:
# 	id	int
# 	member_id	int
# 	loan_amnt	int
# 	funded_amnt	int
# 	funded_amnt_inv	int
# 	term	str
# 	int_rate	float
# 	installment	float
# 	grade	str
# 	sub_grade	str
# 	emp_title	str
# 	emp_length	str
# 	home_ownership	str
# 	annual_inc	int
# 	is_inc_v	str
# 	issue_d	str
# 	loan_status	str
# 	pymnt_plan	str
# 	url	str
# 	desc	str
# 	purpose	str
# 	title	str
# 	zip_code	str
# 	addr_state	str
# 	dti	float
# 	delinq_2yrs	int
# 	earliest_cr_line	str
# 	inq_last_6mths	int
# 	mths_since_last_delinq	int
# 	mths_since_last_record	int
# 	open_acc	int
# 	pub_rec	int
# 	revol_bal	int
# 	revol_util	float
# 	total_acc	int
# 	initial_list_status	str
# 	out_prncp	float
# 	out_prncp_inv	float
# 	total_pymnt	float
# 	total_pymnt_inv	float
# 	total_rec_prncp	float
# 	total_rec_int	float
# 	total_rec_late_fee	float
# 	recoveries	float
# 	collection_recovery_fee	float
# 	last_pymnt_d	str
# 	last_pymnt_amnt	float
# 	next_pymnt_d	str
# 	last_credit_pull_d	str
# 	collections_12_mths_ex_med	int
# ...

# %%
# Reassigning the labels for Safe and Risky loans
loans['safe_loans']=loans['bad_loans'].apply(lambda x:+1 if x==0 else -1)
loans=loans.remove_column('bad_loans')

# %%
# Considering only 4 features
features = ['grade',              # grade of the loan
            'term',               # the term of the loan
            'home_ownership',     # home_ownership status: own, mortgage or rent
            'emp_length',         # number of years of employment
           ]
target = 'safe_loans'

# %%
# Extracting the data with required features
loans=loans[features+[target]]
loans.dtype
# Out:
# <bound method SFrame.dtype of Columns:
# 	grade	str
# 	term	str
# 	home_ownership	str
# 	emp_length	str
# 	safe_loans	int
#
# Rows: 122607
#
# Data:
# +-------+------------+----------------+------------+------------+
# | grade |    term    | home_ownership | emp_length | safe_loans |
# +-------+------------+----------------+------------+------------+
# |   B   |  36 months |      RENT      | 10+ years  |     1      |
# |   C   |  60 months |      RENT      |  < 1 year  |     -1     |
# |   C   |  36 months |      RENT      | 10+ years  |     1      |
# |   C   |  36 months |      RENT      | 10+ years  |     1      |
# |   A   |  36 months |      RENT      |  3 years   |     1      |
# |   E   |  36 months |      RENT      |  9 years   |     1      |
# |   F   |  60 months |      OWN       |  4 years   |     -1     |
# |   B   |  60 months |      RENT      |  < 1 year  |     -1     |
# |   C   |  60 months |      OWN       |  5 years   |     1      |
# ...

# %% [markdown]
# ## Subsample dataset to make sure classes are balanced

# %%
safe_loans_raw=loans[loans[target]==1]
risky_loans_raw=loans[loans[target]==-1]

# Since there are less risky loans than safe loans, find the ratio of the sizes
#and use that percentage to undersample the safe loans.
percentage=len(risky_loans_raw)/float(len(safe_loans_raw))
safe_loans = safe_loans_raw.sample(percentage,seed=1)
risky_loans=risky_loans_raw
loans_data=risky_loans.append(safe_loans)

# %% [markdown]
# ## Transforming Categorical data in binary features

# %%
loans_data.column_names
# Out:
# <bound method SFrame.column_names of Columns:
# 	grade	str
# 	term	str
# 	home_ownership	str
# 	emp_length	str
# 	safe_loans	int
#
# Rows: 46508
#
# Data:
# +-------+------------+----------------+------------+------------+
# | grade |    term    | home_ownership | emp_length | safe_loans |
# +-------+------------+----------------+------------+------------+
# |   C   |  60 months |      RENT      |  < 1 year  |     -1     |
# |   F   |  60 months |      OWN       |  4 years   |     -1     |
# |   B   |  60 months |      RENT      |  < 1 year  |     -1     |
# |   C   |  36 months |      RENT      |  < 1 year  |     -1     |
# |   B   |  36 months |      RENT      |  3 years   |     -1     |
# |   B   |  36 months |      RENT      | 10+ years  |     -1     |
# |   B   |  36 months |      RENT      |   1 year   |     -1     |
# |   C   |  36 months |      RENT      |  9 years   |     -1     |
# |   D   |  60 months |      RENT      |  2 years   |     -1     |
# ...
