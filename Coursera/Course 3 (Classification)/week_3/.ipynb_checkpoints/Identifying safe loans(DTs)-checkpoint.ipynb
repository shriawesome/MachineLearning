# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
loans=pd.read_csv('data_set/lending-club-data.csv')
loans.head()
# Out:
# /Users/shri/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (19,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000             4975   36 months
# 1  1077430    1314167       2500         2500             2500   60 months
# 2  1077175    1313524       2400         2400             2400   36 months
# 3  1076863    1277178      10000        10000            10000   36 months
# 4  1075269    1311441       5000         5000             5000   36 months
#
#    int_rate  installment grade sub_grade          ...          sub_grade_num  \
# 0     10.65       162.87     B        B2          ...                    0.4
# 1     15.27        59.83     C        C4          ...                    0.8
# ...

# %%
loans.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade', 'emp_title',
#        'emp_length', 'home_ownership', 'annual_inc', 'is_inc_v', 'issue_d',
#        'loan_status', 'pymnt_plan', 'url', 'desc', 'purpose', 'title',
#        'zip_code', 'addr_state', 'dti', 'delinq_2yrs', 'earliest_cr_line',
#        'inq_last_6mths', 'mths_since_last_delinq', 'mths_since_last_record',
#        'open_acc', 'pub_rec', 'revol_bal', 'revol_util', 'total_acc',
#        'initial_list_status', 'out_prncp', 'out_prncp_inv', 'total_pymnt',
#        'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int',
#        'total_rec_late_fee', 'recoveries', 'collection_recovery_fee',
#        'last_pymnt_d', 'last_pymnt_amnt', 'next_pymnt_d', 'last_credit_pull_d',
#        'collections_12_mths_ex_med', 'mths_since_last_major_derog',
#        'policy_code', 'not_compliant', 'status', 'inactive_loans', 'bad_loans',
# ...

# %%
loans['safe_loans']=loans['bad_loans'].apply(lambda x:+1 if x==0 else -1)

# %%
loans=loans.drop(columns='bad_loans')

# %%
loans.drop(columns=['bad_loans'],axis=1)
# Out:
#               id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0        1077501    1296599       5000         5000             4975
# 1        1077430    1314167       2500         2500             2500
# 2        1077175    1313524       2400         2400             2400
# 3        1076863    1277178      10000        10000            10000
# 4        1075269    1311441       5000         5000             5000
# 5        1072053    1288686       3000         3000             3000
# 6        1071795    1306957       5600         5600             5600
# 7        1071570    1306721       5375         5375             5350
# 8        1070078    1305201       6500         6500             6500
# 9        1069908    1305008      12000        12000            12000
# 10       1064687    1298717       9000         9000             9000
# 11       1069866    1304956       3000         3000             3000
# 12       1069057    1303503      10000        10000            10000
# ...

# %%
loans.groupby('safe_loans').size()/loans.shape[0]*100
# Out:
# safe_loans
# -1    18.881467
#  1    81.118533
# dtype: float64

# %%
loans.shape[0]
# Out:
# 122607

# %% [markdown]
# ## Features to be used

# %%
features = ['grade',                     # grade of the loan
            'sub_grade',                 # sub-grade of the loan
            'short_emp',                 # one year or less of employment
            'emp_length_num',            # number of years of employment
            'home_ownership',            # home_ownership status: own, mortgage or rent
            'dti',                       # debt to income ratio
            'purpose',                   # the purpose of the loan
            'term',                      # the term of the loan
            'last_delinq_none',          # has borrower had a delinquincy
            'last_major_derog_none',     # has borrower had 90 day or worse rating
            'revol_util',                # percent of available credit being used
            'total_rec_late_fee',        # total late fees received to day
           ]

target = 'safe_loans'

# %%
loans=loans[features+[target]]

# %%
loans.columns
# Out:
# Index(['grade', 'sub_grade', 'short_emp', 'emp_length_num', 'home_ownership',
#        'dti', 'purpose', 'term', 'last_delinq_none', 'last_major_derog_none',
#        'revol_util', 'total_rec_late_fee', 'safe_loans'],
#       dtype='object')

# %% [markdown]
# ## Importing the training and the validation set

# %%
train_idx=pd.read_json('data_set/module-5-assignment-1-train-idx.json')[0]

# %%
train_data=loans.iloc[train_idx]

# %%
validation_idx=pd.read_json('data_set/module-5-assignment-1-validation-idx.json')[0]

# %%
validation_data=loans.iloc[validation_idx]

# %% [markdown]
# ## Building a Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
decision_tree_model=DecisionTreeClassifier(max_depth=6)

# %%
x_train=np.array(train_data[features])

# %%
y_train=np.array(train_data[target])

# %%
decision_tree_model.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-d5517800ec03> in <module>()
# ----> 1 decision_tree_model.fit(x_train,y_train)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     788             sample_weight=sample_weight,
#     789             check_input=check_input,
# --> 790             X_idx_sorted=X_idx_sorted)
#     791         return self
#     792
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     114         random_state = check_random_state(self.random_state)
#     115         if check_input:
# --> 116             X = check_array(X, dtype=DTYPE, accept_sparse="csc")
#     117             y = check_array(y, ensure_2d=False, dtype=None)
#     118             if issparse(X):
#
# ...

# %%
train_data.dtypes
# Out:
# grade                     object
# sub_grade                 object
# short_emp                  int64
# emp_length_num             int64
# home_ownership            object
# dti                      float64
# purpose                   object
# term                      object
# last_delinq_none           int64
# last_major_derog_none      int64
# revol_util               float64
# total_rec_late_fee       float64
# safe_loans                 int64
# dtype: object

# %%
train_data['term_float']=train_data['term'].apply(lambda x:+1 if str(x)=='60 months' else 0)
# Out:
# /Users/shri/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## Converting string 'term' to float for DT in scikit learn

# %%
train_data['term_float']=train_data['term'].apply(lambda x: 0 if x==' 36 months' else 1)

# %%
train_data['term_float'].head()
# Out:
# 1     1
# 6     1
# 7     1
# 10    0
# 12    0
# Name: term_float, dtype: int64

# %%
train_data=train_data.drop(columns=['term'],axis=1)

# %%
features = ['grade',                     # grade of the loan
            'sub_grade',                 # sub-grade of the loan
            'short_emp',                 # one year or less of employment
            'emp_length_num',            # number of years of employment
            'home_ownership',            # home_ownership status: own, mortgage or rent
            'dti',                       # debt to income ratio
            'purpose',                   # the purpose of the loan
            'term_float',                      # the term of the loan
            'last_delinq_none',          # has borrower had a delinquincy
            'last_major_derog_none',     # has borrower had 90 day or worse rating
            'revol_util',                # percent of available credit being used
            'total_rec_late_fee',        # total late fees received to day
           ]

x_train=np.array(train_data[features])

# %%
decision_tree_model.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-96-d5517800ec03> in <module>()
# ----> 1 decision_tree_model.fit(x_train,y_train)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     788             sample_weight=sample_weight,
#     789             check_input=check_input,
# --> 790             X_idx_sorted=X_idx_sorted)
#     791         return self
#     792
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     114         random_state = check_random_state(self.random_state)
#     115         if check_input:
# --> 116             X = check_array(X, dtype=DTYPE, accept_sparse="csc")
#     117             y = check_array(y, ensure_2d=False, dtype=None)
#     118             if issparse(X):
#
# ...

# %%
train_data.dtypes
# Out:
# grade                     object
# sub_grade                 object
# short_emp                  int64
# emp_length_num             int64
# home_ownership            object
# dti                      float64
# purpose                   object
# last_delinq_none           int64
# last_major_derog_none      int64
# revol_util               float64
# total_rec_late_fee       float64
# safe_loans                 int64
# term_float                 int64
# dtype: object

# %%
train_data.groupby('home_ownership').count()
# Out:
#                 grade  sub_grade  short_emp  emp_length_num    dti  purpose  \
# home_ownership
# MORTGAGE        17378      17378      17378           17378  17378    17378
# OTHER              61         61         61              61     61       61
# OWN              3075       3075       3075            3075   3075     3075
# RENT            16710      16710      16710           16710  16710    16710
#
#                 last_delinq_none  last_major_derog_none  revol_util  \
# home_ownership
# MORTGAGE                   17378                  17378       17378
# OTHER                         61                     61          61
# OWN                         3075                   3075        3075
# RENT                       16710                  16710       16710
#
#                 total_rec_late_fee  safe_loans  term_float
# home_ownership
# MORTGAGE                     17378       17378       17378
# OTHER                           61          61          61
# ...

# %%
train_data['purpose'].unique()
# Out:
# array(['car', 'small_business', 'other', 'debt_consolidation',
#        'major_purchase', 'credit_card', 'home_improvement', 'moving',
#        'house', 'medical', 'wedding', 'vacation'], dtype=object)

# %%
from sklearn import preprocessing
purpose_values=preprocessing.LabelEncoder()
purpose_values.fit(train_data['purpose'].unique())
# Out:
# LabelEncoder()

# %%
train_data['purpose_encoder']=purpose_values.transform(train_data['purpose'])

# %%
features = ['grade',                     # grade of the loan
            'sub_grade',                 # sub-grade of the loan
            'short_emp',                 # one year or less of employment
            'emp_length_num',            # number of years of employment
            'home_ownership',            # home_ownership status: own, mortgage or rent
            'dti',                       # debt to income ratio
            'purpose_encoder',                   # the purpose of the loan
            'term_float',                      # the term of the loan
            'last_delinq_none',          # has borrower had a delinquincy
            'last_major_derog_none',     # has borrower had 90 day or worse rating
            'revol_util',                # percent of available credit being used
            'total_rec_late_fee',        # total late fees received to day
           ]

x_train=np.array(train_data[features])
decision_tree_model.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-125-438f79e4dcd9> in <module>()
#      14
#      15 x_train=np.array(train_data[features])
# ---> 16 decision_tree_model.fit(x_train,y_train)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     788             sample_weight=sample_weight,
#     789             check_input=check_input,
# --> 790             X_idx_sorted=X_idx_sorted)
#     791         return self
#     792
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     114         random_state = check_random_state(self.random_state)
#     115         if check_input:
# --> 116             X = check_array(X, dtype=DTYPE, accept_sparse="csc")
# ...

# %% [markdown]
# ### Converting 'home_mortgage' to int/float

# %%
train_data.groupby('home_ownership').count()
# Out:
#                 grade  sub_grade  short_emp  emp_length_num    dti  purpose  \
# home_ownership
# MORTGAGE        17378      17378      17378           17378  17378    17378
# OTHER              61         61         61              61     61       61
# OWN              3075       3075       3075            3075   3075     3075
# RENT            16710      16710      16710           16710  16710    16710
#
#                 last_delinq_none  last_major_derog_none  revol_util  \
# home_ownership
# MORTGAGE                   17378                  17378       17378
# OTHER                         61                     61          61
# OWN                         3075                   3075        3075
# RENT                       16710                  16710       16710
#
#                 total_rec_late_fee  safe_loans  term_float  purpose_encoder
# home_ownership
# MORTGAGE                     17378       17378       17378            17378
# ...

# %%
home_encode=preprocessing.LabelEncoder()

# %%
home_encode.fit(train_data['home_ownership'].unique())
# Out:
# LabelEncoder()

# %%
train_data['home_ownership_encoder']=home_encode.transform(train_data['home_ownership'])

# %%
features = ['grade',                     # grade of the loan
            'sub_grade',                 # sub-grade of the loan
            'short_emp',                 # one year or less of employment
            'emp_length_num',            # number of years of employment
            'home_ownership_encoder',            # home_ownership status: own, mortgage or rent
            'dti',                       # debt to income ratio
            'purpose_encoder',                   # the purpose of the loan
            'term_float',                      # the term of the loan
            'last_delinq_none',          # has borrower had a delinquincy
            'last_major_derog_none',     # has borrower had 90 day or worse rating
            'revol_util',                # percent of available credit being used
           ]

# %%
train_data['sub_grade'].unique()
# Out:
# array(['C4', 'F2', 'B5', 'C1', 'B2', 'B4', 'B3', 'C2', 'B1', 'C5', 'E4',
#        'D3', 'D2', 'D5', 'A2', 'C3', 'A3', 'A5', 'A4', 'E1', 'D1', 'E5',
#        'D4', 'F1', 'E3', 'G2', 'E2', 'F5', 'F4', 'F3', 'G4', 'G3', 'G1',
#        'A1', 'G5'], dtype=object)

# %%
train_data['grade'].unique()
# Out:
# array(['C', 'F', 'B', 'E', 'D', 'A', 'G'], dtype=object)

# %%
sub_encode=preprocessing.LabelEncoder()
grade_encode=preprocessing.LabelEncoder()

# %%
sub_encode.fit(train_data['sub_grade'].unique())
grade_encode.fit(train_data['grade'].unique())
# Out:
# LabelEncoder()

# %%
train_data['sub_grade_encoder']=sub_encode.transform(train_data['sub_grade'])
train_data['grade_encoder']=grade_encode.transform(train_data['grade'])

# %%
features = ['grade_encoder',                     # grade of the loan
            'sub_grade_encoder',                 # sub-grade of the loan
            'short_emp',                 # one year or less of employment
            'emp_length_num',            # number of years of employment
            'home_ownership_encoder',            # home_ownership status: own, mortgage or rent
            'dti',                       # debt to income ratio
            'purpose_encoder',                   # the purpose of the loan
            'term_float',                      # the term of the loan
            'last_delinq_none',          # has borrower had a delinquincy
            'last_major_derog_none',     # has borrower had 90 day or worse rating
            'revol_util',                # percent of available credit being used
            'total_rec_late_fee',        # total late fees received to day
           ]

x_train=np.array(train_data[features])
decision_tree_model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=6,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
small_model=DecisionTreeClassifier(max_depth=2)

# %%
small_model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=2,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
from sklearn.externals.six import StringIO
from IPython.display import Image
from sklearn import tree
import pydotplus

# %%
dot_data=StringIO
dot_data=tree.export_graphviz(decision_tree_model,out_file=None,
               feature_names=features,class_names=target)
graph=pydotplus.graph_from_dot_data(dot_data)
Image(graph.create_png())

# %%
graph.write_pdf('tree_visualisation.pdf')
# Out:
# ...
# True

# %% [markdown]
# ## Make predictions

# %%
#Grabbing two +ve and -ve set from the validation set
validation_safe_loans=validation_data[validation_data[target]==1]
validation_risky_loans=validation_data[validation_data[target]==-1]
sample_validation_data_risky=validation_risky_loans[0:2]
sample_validation_data_safe=validation_safe_loans[0:2]
sample_validation_data=sample_validation_data_safe.append(sample_validation_data_risky)
sample_validation_data
# Out:
#    grade sub_grade  short_emp  emp_length_num home_ownership    dti  \
# 19     B        B3          0              11            OWN  11.18
# 79     D        D1          0              10           RENT  16.85
# 24     D        D2          0               3           RENT  13.97
# 41     A        A5          0              11       MORTGAGE  16.33
#
#                purpose        term  last_delinq_none  last_major_derog_none  \
# 19         credit_card   36 months                 1                      1
# 79  debt_consolidation   36 months                 1                      1
# 24               other   60 months                 0                      1
# 41  debt_consolidation   36 months                 1                      1
#
#     revol_util  total_rec_late_fee  safe_loans
# 19        82.4                 0.0           1
# 79        96.4                 0.0           1
# 24        59.5                 0.0          -1
# 41        62.1                 0.0          -1

# %%
features
# Out:
# ['grade_encoder',
#  'sub_grade_encoder',
#  'short_emp',
#  'emp_length_num',
#  'home_ownership_encoder',
#  'dti',
#  'purpose_encoder',
#  'term_float',
#  'last_delinq_none',
#  'last_major_derog_none',
#  'revol_util',
#  'total_rec_late_fee']

# %%
sample_validation_data['grade_encoder']=grade_encode.transform(sample_validation_data['grade'])
sample_validation_data['sub_grade_encoder']=sub_encode.transform(sample_validation_data['sub_grade'])
sample_validation_data['home_ownership_encoder']=home_encode.transform(sample_validation_data['home_ownership'])
sample_validation_data['purpose_encoder']=purpose_values.transform(sample_validation_data['purpose'])

# %%
term_encoder=preprocessing.LabelEncoder()
term_encoder.fit(validation_data['term'].unique())
# Out:
# LabelEncoder()

# %%
sample_validation_data['term_float']=term_encoder.transform(sample_validation_data['term'])

# %%
decision_tree_model.predict(sample_validation_data[features])
# Out:
# array([ 1,  1, -1,  1])

# %% [markdown]
# ### Quiz Question: What percentage of the predictions on sample_validation_data did decision_tree_model get correct?

# %%
predictions=[1,1,-1,1]
sample_validation_data[target]
#Percentage of correct predictions
#print(3/4*100)
# Out:
# 19    1
# 79    1
# 24   -1
# 41   -1
# Name: safe_loans, dtype: int64

# %% [markdown]
# ### Quiz Question: Which loan has the highest probability of being classified as a safe loan?

# %%
decision_tree_model.predict_proba(sample_validation_data[features])
# Out:
# array([[0.32493298, 0.67506702],
#        [0.47687535, 0.52312465],
#        [0.61556064, 0.38443936],
#        [0.20821918, 0.79178082]])

# %%
sample_validation_data.iloc[1]
# Out:
# grade                                      D
# sub_grade                                 D1
# short_emp                                  0
# emp_length_num                            10
# home_ownership                          RENT
# dti                                    16.85
# purpose                   debt_consolidation
# term                               36 months
# last_delinq_none                           1
# last_major_derog_none                      1
# revol_util                              96.4
# total_rec_late_fee                         0
# safe_loans                                 1
# grade_encoder                              3
# sub_grade_encoder                         15
# home_ownership_encoder                     3
# purpose_encoder                            2
# term_float                                 0
# Name: 79, dtype: object

# %%
small_model.predict(sample_validation_data[features]) # 50% accuracy
# Out:
# array([ 1, -1, -1,  1])

# %%
validation_data['grade_encoder']=grade_encode.transform(validation_data['grade'])
validation_data['sub_grade_encoder']=sub_encode.transform(validation_data['sub_grade'])
validation_data['home_ownership_encoder']=home_encode.transform(validation_data['home_ownership'])
validation_data['purpose_encoder']=purpose_values.transform(validation_data['purpose'])
validation_data['term_float']=term_encoder.transform(validation_data['term'])
# Out:
# /Users/shri/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Users/shri/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/shri/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
predict_7=decision_tree_model.predict(validation_data[features])
predict_small=small_model.predict(validation_data[features])

# %%
def accuracy(predictions,output):
    total_count=predictions.shape[0]
    total_

# %%
from sklearn.metrics import accuracy_score
accuracy_score(predict_7,validation_data[target])
# Out:
# 0.6324859974149074

# %%
accuracy_score(predict_small,validation_data[target])
# Out:
# 0.6148211977595864

# %% [markdown]
# ### Evaluating Accuracy of complex decision tree model

# %%
big_model=DecisionTreeClassifier(max_depth=10)
big_model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=10,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
big_model.score(x_train,y_train)
# Out:
# 0.6730603911454975

# %%
decision_tree_model.score(x_train,y_train)
# Out:
# 0.6417633784655061

# %% [markdown]
# ### Quiz Question: How does the performance of big_model on the validation set compare to decision_tree_model on the validation set? Is this a sign of overfitting?

# %%
big_model.score(validation_data[features],validation_data[target])
# Out:
# 0.6267772511848341

# %% [markdown]
# ## Quantifying the cost of mistakes

# %%
from sklearn.metrics import confusion_matrix
tn,fp,fn,tp=confusion_matrix(predict_7,validation_data[target]).ravel()

# %%
tn,fp,fn,tp
# Out:
# (2826, 1564, 1848, 3046)

# %% [markdown]
# ### Quiz Question: Let's assume that each mistake costs us money: a false negative costs \\$10,000, while a false positive positive costs $20,000. What is the total cost of mistakes made by decision_tree_model on validation_data?

# %%
total_cost_mistakes=(fp*20000)+(fn*10000)
total_cost_mistakes
# Out:
# 49760000
